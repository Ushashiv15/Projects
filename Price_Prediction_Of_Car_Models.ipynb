# %%
import pandas as pd
import numpy as np

# %%
d= pd.read_csv('/fiat500.csv')
d
# Out:
#         ID   model  engine_power  age_in_days      km  previous_owners  \
# 0        1  lounge            51          882   25000                1
# 1        2     pop            51         1186   32500                1
# 2        3   sport            74         4658  142228                1
# 3        4  lounge            51         2739  160000                1
# 4        5     pop            73         3074  106880                1
# ...    ...     ...           ...          ...     ...              ...
# 1533  1534   sport            51         3712  115280                1
# 1534  1535  lounge            74         3835  112000                1
# 1535  1536     pop            51         2223   60457                1
# 1536  1537  lounge            51         2557   80750                1
# 1537  1538     pop            51         1766   54276                1
#
#             lat        lon  price
# 0     44.907242   8.611560   8900
# 1     45.666359  12.241890   8800
# ...

# %%
d.shape
# Out:
# (1538, 9)

# %%
d.size
# Out:
# 13842

# %%
d.describe()
# Out:
#                 ID  engine_power  age_in_days             km  previous_owners  \
# count  1538.000000   1538.000000  1538.000000    1538.000000      1538.000000
# mean    769.500000     51.904421  1650.980494   53396.011704         1.123537
# std     444.126671      3.988023  1289.522278   40046.830723         0.416423
# min       1.000000     51.000000   366.000000    1232.000000         1.000000
# 25%     385.250000     51.000000   670.000000   20006.250000         1.000000
# 50%     769.500000     51.000000  1035.000000   39031.000000         1.000000
# 75%    1153.750000     51.000000  2616.000000   79667.750000         1.000000
# max    1538.000000     77.000000  4658.000000  235000.000000         4.000000
#
#                lat          lon         price
# count  1538.000000  1538.000000   1538.000000
# mean     43.541361    11.563428   8576.003901
# std       2.133518     2.328190   1939.958641
# min      36.855839     7.245400   2500.000000
# ...

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1538 entries, 0 to 1537
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               1538 non-null   int64
#  1   model            1538 non-null   object
#  2   engine_power     1538 non-null   int64
#  3   age_in_days      1538 non-null   int64
#  4   km               1538 non-null   int64
#  5   previous_owners  1538 non-null   int64
#  6   lat              1538 non-null   float64
#  7   lon              1538 non-null   float64
#  8   price            1538 non-null   int64
# dtypes: float64(2), int64(6), object(1)
# memory usage: 108.3+ KB

# %%
d.head()
# Out:
#    ID   model  engine_power  age_in_days      km  previous_owners        lat  \
# 0   1  lounge            51          882   25000                1  44.907242
# 1   2     pop            51         1186   32500                1  45.666359
# 2   3   sport            74         4658  142228                1  45.503300
# 3   4  lounge            51         2739  160000                1  40.633171
# 4   5     pop            73         3074  106880                1  41.903221
#
#          lon  price
# 0   8.611560   8900
# 1  12.241890   8800
# 2  11.417840   4200
# 3  17.634609   6000
# 4  12.495650   5700

# %%
d.tail()
# Out:
#         ID   model  engine_power  age_in_days      km  previous_owners  \
# 1533  1534   sport            51         3712  115280                1
# 1534  1535  lounge            74         3835  112000                1
# 1535  1536     pop            51         2223   60457                1
# 1536  1537  lounge            51         2557   80750                1
# 1537  1538     pop            51         1766   54276                1
#
#             lat       lon  price
# 1533  45.069679   7.70492   5200
# 1534  45.845692   8.66687   4600
# 1535  45.481541   9.41348   7500
# 1536  45.000702   7.68227   5990
# 1537  40.323410  17.56827   7900

# %%
list(d)
# Out:
# ['ID',
#  'model',
#  'engine_power',
#  'age_in_days',
#  'km',
#  'previous_owners',
#  'lat',
#  'lon',
#  'price']

# %%
set(d)
# Out:
# {'ID',
#  'age_in_days',
#  'engine_power',
#  'km',
#  'lat',
#  'lon',
#  'model',
#  'previous_owners',
#  'price'}

# %%
dict(d)
# Out:
# {'ID': 0          1
#  1          2
#  2          3
#  3          4
#  4          5
#          ...
#  1533    1534
#  1534    1535
#  1535    1536
#  1536    1537
#  1537    1538
#  Name: ID, Length: 1538, dtype: int64,
#  'model': 0       lounge
#  1          pop
#  2        sport
#  3       lounge
#  4          pop
#           ...
#  1533     sport
#  1534    lounge
#  1535       pop
#  1536    lounge
#  1537       pop
#  Name: model, Length: 1538, dtype: object,
#  'engine_power': 0       51
#  1       51
#  2       74
#  3       51
#  4       73
#          ..
#  1533    51
#  1534    74
#  1535    51
#  1536    51
#  1537    51
#  Name: engine_power, Length: 1538, dtype: int64,
#  'age_in_days': 0        882
#  1       1186
#  2       4658
#  3       2739
#  4       3074
#          ...
#  1533    3712
#  1534    3835
#  1535    2223
#  1536    2557
#  1537    1766
#  Name: age_in_days, Length: 1538, dtype: int64,
#  'km': 0        25000
#  1        32500
#  2       142228
# ...

# %%
d['model'].unique()
# Out:
# array(['lounge', 'pop', 'sport'], dtype=object)

# %%
d['previous_owners'].unique()
# Out:
# array([1, 2, 3, 4])

# %%
d.groupby('model').count()
# Out:
#           ID  engine_power  age_in_days    km  previous_owners   lat   lon  \
# model
# lounge  1094          1094         1094  1094             1094  1094  1094
# pop      358           358          358   358              358   358   358
# sport     86            86           86    86               86    86    86
#
#         price
# model
# lounge   1094
# pop       358
# sport      86

# %%
d.groupby('previous_owners').count()
# Out:
#                    ID  model  engine_power  age_in_days    km   lat   lon  \
# previous_owners
# 1                1389   1389          1389         1389  1389  1389  1389
# 2                 117    117           117          117   117   117   117
# 3                  23     23            23           23    23    23    23
# 4                   9      9             9            9     9     9     9
#
#                  price
# previous_owners
# 1                 1389
# 2                  117
# 3                   23
# 4                    9

# %%
d.groupby('model').sum()
# Out:
#             ID  engine_power  age_in_days        km  previous_owners  \
# model
# lounge  847772         56413      1572702  51279549             1222
# pop     273420         18646       681814  21952596              397
# sport    62299          4770       284692   8890921              109
#
#                  lat           lon    price
# model
# lounge  47570.864239  12666.948732  9790738
# pop     15628.987026   4134.049396  2859471
# sport    3766.762455    983.554663   539685

# %%
d=pd.get_dummies(d,dtype='int')
d
# Out:
#         ID  engine_power  age_in_days      km  previous_owners        lat  \
# 0        1            51          882   25000                1  44.907242
# 1        2            51         1186   32500                1  45.666359
# 2        3            74         4658  142228                1  45.503300
# 3        4            51         2739  160000                1  40.633171
# 4        5            73         3074  106880                1  41.903221
# ...    ...           ...          ...     ...              ...        ...
# 1533  1534            51         3712  115280                1  45.069679
# 1534  1535            74         3835  112000                1  45.845692
# 1535  1536            51         2223   60457                1  45.481541
# 1536  1537            51         2557   80750                1  45.000702
# 1537  1538            51         1766   54276                1  40.323410
#
#             lon  price  model_lounge  model_pop  model_sport
# ...

# %%
cor=d.corr()
cor
# Out:
#                        ID  engine_power  age_in_days        km  \
# ID               1.000000     -0.034059    -0.060753 -0.006537
# engine_power    -0.034059      1.000000     0.319190  0.285495
# age_in_days     -0.060753      0.319190     1.000000  0.833890
# km              -0.006537      0.285495     0.833890  1.000000
# previous_owners  0.007803     -0.005030     0.075775  0.097539
# lat             -0.058207      0.005721     0.062982  0.035519
# lon              0.058941     -0.005032    -0.042667  0.004839
# price            0.028516     -0.277235    -0.893328 -0.859373
# model_lounge     0.019193     -0.133321    -0.259863 -0.255746
# model_pop       -0.007142      0.024783     0.108327  0.109024
# model_sport     -0.024718      0.217362     0.313276  0.303874
#
#                  previous_owners       lat       lon     price  model_lounge  \
# ID                      0.007803 -0.058207  0.058941  0.028516      0.019193
# ...

# %%
import seaborn as sns
sns.heatmap(cor,vmax=1,vmin=-1,annot=False,linewidth=5,cmap='bwr')
# Out:
# <Axes: >

# %%
d1=d.drop(['lat','lon','ID'],axis=1)
d1
# Out:
#       engine_power  age_in_days      km  previous_owners  price  model_lounge  \
# 0               51          882   25000                1   8900             1
# 1               51         1186   32500                1   8800             0
# 2               74         4658  142228                1   4200             0
# 3               51         2739  160000                1   6000             1
# 4               73         3074  106880                1   5700             0
# ...            ...          ...     ...              ...    ...           ...
# 1533            51         3712  115280                1   5200             0
# 1534            74         3835  112000                1   4600             1
# 1535            51         2223   60457                1   7500             0
# 1536            51         2557   80750                1   5990             1
# 1537            51         1766   54276                1   7900             0
#
#       model_pop  model_sport
# ...

# %%
d2=d.drop('ID',axis=1)
d2
# Out:
#       engine_power  age_in_days      km  previous_owners        lat  \
# 0               51          882   25000                1  44.907242
# 1               51         1186   32500                1  45.666359
# 2               74         4658  142228                1  45.503300
# 3               51         2739  160000                1  40.633171
# 4               73         3074  106880                1  41.903221
# ...            ...          ...     ...              ...        ...
# 1533            51         3712  115280                1  45.069679
# 1534            74         3835  112000                1  45.845692
# 1535            51         2223   60457                1  45.481541
# 1536            51         2557   80750                1  45.000702
# 1537            51         1766   54276                1  40.323410
#
#             lon  price  model_lounge  model_pop  model_sport
# 0      8.611560   8900             1          0            0
# ...

# %%
x=d1.drop('price',axis=1)
y=d1['price']
y
# Out:
# 0       8900
# 1       8800
# 2       4200
# 3       6000
# 4       5700
#         ...
# 1533    5200
# 1534    4600
# 1535    7500
# 1536    5990
# 1537    7900
# Name: price, Length: 1538, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=0)
x_train
# Out:
#       engine_power  age_in_days      km  previous_owners  model_lounge  \
# 1479            51         1674   89000                1             1
# 431             51         2527   95000                1             1
# 194             51         3227  142000                1             1
# 240             51          397   13105                1             1
# 474             51         1005   60879                1             0
# ...            ...          ...     ...              ...           ...
# 763             62         3227   79000                1             1
# 835             51          366   16500                1             0
# 1216            51         3653  122649                1             1
# 559             51          913   20000                1             0
# 684             51          943   35481                1             0
#
#       model_pop  model_sport
# 1479          0            0
# 431           0            0
# ...

# %%
y_train
# Out:
# 1479     7600
# 431      7500
# 194      4900
# 240     10500
# 474      8350
#         ...
# 763      8500
# 835     10500
# 1216     5300
# 559      8499
# 684      8650
# Name: price, Length: 1030, dtype: int64

# %%
from sklearn.linear_model import LinearRegression
r=LinearRegression()
r.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
yp=r.predict(x_test)

# %%
y_test
# Out:
# 1440     5400
# 54      10600
# 298      9980
# 1335    10400
# 861      9800
#         ...
# 1174     9500
# 1223     9700
# 536     10900
# 1476    10500
# 1061     8990
# Name: price, Length: 508, dtype: int64

# %%
from sklearn.metrics import r2_score
r2_score(y_test,yp)
# Out:
# 0.8449228059289153

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test,yp)
# Out:
# 588483.045136751

# %%
rs=pd.DataFrame(columns=['price','predicted'])
rs['price']=y_test
rs['predicted']=yp
rs=rs.reset_index()
rs['Id']=rs.index
rs
# Out:
#      index  price     predicted   Id
# 0     1440   5400   4539.233542    0
# 1       54  10600  10224.976652    1
# 2      298   9980  10336.327946    2
# 3     1335  10400  10479.913242    3
# 4      861   9800   9842.626683    4
# ..     ...    ...           ...  ...
# 503   1174   9500  10088.510312  503
# 504   1223   9700   9874.583668  504
# 505    536  10900   9762.520194  505
# 506   1476  10500  10101.380111  506
# 507   1061   8990   9490.852965  507
#
# [508 rows x 4 columns]

# %%
sns.lineplot(x='Id',y='price',data=rs.head(50))
sns.lineplot(x='Id',y='predicted',data=rs.head(50))
# Out:
# <Axes: xlabel='Id', ylabel='price'>

# %%
x_test
# Out:
#       engine_power  age_in_days      km  previous_owners  model_lounge  \
# 1440            51         4474  143900                1             1
# 54              51          701   11200                1             1
# 298             51          397   19286                1             1
# 1335            51          366   12950                1             1
# 861             51          821   26333                1             1
# ...            ...          ...     ...              ...           ...
# 1174            51          366   14730                1             0
# 1223            51          640   33007                1             1
# 536             51          943   25006                1             1
# 1476            51          731   16500                1             1
# 1061            51         1278   24162                1             1
#
#       model_pop  model_sport
# 1440          0            0
# 54            0            0
# ...

# %%
new=[[51,3000,65000,1,1,0,0]]

# %%
real=r.predict(new)
real
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([7260.15255767])
